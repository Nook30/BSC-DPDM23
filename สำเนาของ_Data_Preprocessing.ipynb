# %% [markdown]
# <a href="https://colab.research.google.com/github/Nook30/BSC-DPDM23/blob/main/%E0%B8%AA%E0%B8%B3%E0%B9%80%E0%B8%99%E0%B8%B2%E0%B8%82%E0%B8%AD%E0%B8%87_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data_from_gdrive = pd.read_excel('/content/drive/MyDrive/bsc_dpdm23_data/2563.xls',header=2)
data_from_gdrive
# Out:
#     เลขที่คำขอ เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย  \
# 0       610707   62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 1       620660   63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 2       610182   63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# 3       620318   63-0080-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# 4       620185   63-0079-1-00-0-0       เอ็นจีเค สปาร์คปลั๊กส์ (ประเทศไทย)
# ..         ...                ...                                      ...
# 655    E630369   63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 656    E630401   63-0682-1-00-1-0                            โกลว์ พลังงาน
# 657    E630277   63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 658     610552   63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 659    E630269   63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
# ...

# %%
shopping_data = pd.read_csv('/content/drive/MyDrive/bsc_dpdm23_data/customer_shopping_data.csv')

# %%
shopping_data.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
shopping_data .describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# # ข้อมูลบางส่วนมีค่าตัวแปรบางตัวที่ไม่ทราบค่า (Missing Data)

# %%
shopping_data.isnull()
# Out:
#        invoice_no  customer_id  gender    age  category  quantity  price  \
# 0           False        False   False  False     False     False  False
# 1           False        False   False  False     False     False  False
# 2           False        False   False  False     False     False  False
# 3           False        False   False  False     False     False  False
# 4           False        False   False  False     False     False  False
# ...           ...          ...     ...    ...       ...       ...    ...
# 99452       False        False   False  False     False     False  False
# 99453       False        False   False  False     False     False  False
# 99454       False        False   False  False     False     False  False
# 99455       False        False   False  False     False     False  False
# 99456       False        False   False  False     False     False  False
#
#        payment_method  invoice_date  shopping_mall
# ...

# %%
shopping_data.isnull().any()
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
# # เราจะลบ Price ของ records ที่เป็น Clothing,Cash,Metrocity ออก เพื่อจำลอง Missing Data

# %%
shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash ') &
              (shopping_data['shopping_mall']=='Metrociyt')]
# Out:
# Empty DataFrame
# Columns: [invoice_no, customer_id, gender, age, category, quantity, price, payment_method, invoice_date, shopping_mall]
# Index: []

# %%
shopping_new = shopping_data[shopping_data['category']=='Clothing']
shopping_new2=shopping_new[shopping_new['payment_method']=='Cash']
shopping_new3 = shopping_new2[shopping_new2['shopping_mall']=='Metrocity']
shopping_new3
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 2        I127801     C266599    Male   20  Clothing         1   300.08
# 382      I591015     C286181  Female   69  Clothing         1   300.08
# 446      I423124     C109593  Female   66  Clothing         1   300.08
# 531      I223795     C280596    Male   40  Clothing         3   900.24
# 647      I891465     C175833  Female   19  Clothing         1   300.08
# ...          ...         ...     ...  ...       ...       ...      ...
# 98987    I693615     C323954  Female   33  Clothing         2   600.16
# 99153    I922072     C336171    Male   47  Clothing         4  1200.32
# 99178    I135939     C211085    Male   40  Clothing         3   900.24
# 99339    I287566     C216529  Female   48  Clothing         1   300.08
# 99390    I283542     C780439    Male   35  Clothing         1   300.08
#
#       payment_method invoice_date shopping_mall
# 2               Cash    9/11/2021     Metrocity
# ...

# %% [markdown]
# แยก data ส่วนที่ไม่ missing ออกมา

# %%
nomissing=shopping_data[(shopping_data['category']!='Clothing') |
                        (shopping_data['payment_method']!='Cash') |
                        (shopping_data['shopping_mall']!='Metrocity')]

# %% [markdown]
# 1.ลบออกไปเลย

# %% [markdown]
# 2.เติมด้วย unknow *เราจะเติมกับข้อมูล categorica'

# %% [markdown]
# 3.เติมด้วยค่าเฉลี่ย

# %% [markdown]
# 4.เติมด้วยค่าเฉลี่ยของกลุ่ม

# %% [markdown]
# # Quiz
#
# 1. mean หลังเติมด้วยค่าเฉลี่ย Clothing
# 2. mean หลังเติมด้วยค่าเฉลี่ย Cash
# 3. mean หลังเติมด้วยค่าเฉลี่ย Megacity
# 4. mean หลังเติมด้วยค่าเฉลี่ย Cash+Megacity

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลมีความซ้ำซ้อน (Duplicate Data)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลบางตัวในชุดข้อมูลมีลักษณะผิดปกติหรือแตกต่างจากข้อมูลส่วนใหญ่ (Outlier)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ค่าตัวแปรบางตัวที่ไม่ถูกต้อง (Erroneous Data)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลมีค่าตัวแปรไม่สอดคล้องซึ่งกันและกัน (Inconsistent)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix
