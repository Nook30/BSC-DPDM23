# %% [markdown]
# <a href="https://colab.research.google.com/github/Nook30/BSC-DPDM23/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [ข้อความลิงก์](https://drive.google.com/drive/u/0/home![f7dd0226-69c2-423b-b727-36e8fa784887.jpg](data:image/jpeg;base64,...))

# %% [markdown]
# ![image.png](data:image/png;base64,...)
